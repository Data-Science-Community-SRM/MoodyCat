# %%
import os
import matplotlib.pyplot as plt

# %%
classes=['Angry','Fear','Happy','Neutral','Sad','Surprise']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
angry_validation='/content/drive/My Drive/final_data_v2/Validation/angry'
fear_validation='/content/drive/My Drive/final_data_v2/Validation/fear'
happy_validation='/content/drive/My Drive/final_data_v2/Validation/happy'
neutral_validation='/content/drive/My Drive/final_data_v2/Validation/neutral'
sad_validation='/content/drive/My Drive/final_data_v2/Validation/sad'
surprise_validation='/content/drive/My Drive/final_data_v2/Validation/surprise'

angry_in_val= len([files for files in os.listdir(angry_validation)])
fear_in_val= len([files for files in os.listdir(fear_validation)])
happy_in_val= len([files for files in os.listdir(happy_validation)])
neutral_in_val= len([files for files in os.listdir(neutral_validation)])
sad_in_val= len([files for files in os.listdir(sad_validation)])
surprise_in_val= len([files for files in os.listdir(surprise_validation)])

# %%
angry_Train='/content/drive/My Drive/final_data_v2/Train/angry'
fear_Train='/content/drive/My Drive/final_data_v2/Train/fear'
happy_Train='/content/drive/My Drive/final_data_v2/Train/happy'
neutral_Train='/content/drive/My Drive/final_data_v2/Train/neutral'
sad_Train='/content/drive/My Drive/final_data_v2/Train/sad'
surprise_Train='/content/drive/My Drive/final_data_v2/Train/surprise'

angry_in_Train= len([files for files in os.listdir(angry_Train)])
fear_in_Train= len([files for files in os.listdir(fear_Train)])
happy_in_Train= len([files for files in os.listdir(happy_Train)])
neutral_in_Train= len([files for files in os.listdir(neutral_Train)])
sad_in_Train= len([files for files in os.listdir(sad_Train)])
surprise_in_Train= len([files for files in os.listdir(surprise_Train)])

# %%
angry_Test='/content/drive/My Drive/final_data_v2/Test/angry'
fear_Test='/content/drive/My Drive/final_data_v2/Test/fear'
happy_Test='/content/drive/My Drive/final_data_v2/Test/happy'
neutral_Test='/content/drive/My Drive/final_data_v2/Test/neutral'
sad_Test='/content/drive/My Drive/final_data_v2/Test/sad'
surprise_Test='/content/drive/My Drive/final_data_v2/Test/surprise'

angry_in_Test= len([files for files in os.listdir(angry_Test)])
fear_in_Test= len([files for files in os.listdir(fear_Test)])
happy_in_Test= len([files for files in os.listdir(happy_Test)])
neutral_in_Test= len([files for files in os.listdir(neutral_Test)])
sad_in_Test= len([files for files in os.listdir(sad_Test)])
surprise_in_Test= len([files for files in os.listdir(surprise_Test)])

# %%
plt.bar(classes, [angry_in_Test,fear_in_Test,happy_in_Test,neutral_in_Test,sad_in_Test,surprise_in_Test], color ='blue',  
        width = 0.7) 
print([angry_in_Test,fear_in_Test,happy_in_Test,neutral_in_Test,sad_in_Test,surprise_in_Test])
plt.xlabel("Classes") 
plt.ylabel("Number of images") 
plt.title("Test Set") 
plt.show()
# Out:
# [495, 511, 619, 619, 607, 400]

# %%
plt.bar(classes, [angry_in_Train,fear_in_Train,happy_in_Train,neutral_in_Train,sad_in_Train,surprise_in_Train], color ='blue',  
        width = 0.7) 
print(angry_in_Train,fear_in_Train,happy_in_Train,neutral_in_Train,sad_in_Train,surprise_in_Train)  
plt.xlabel("Classes") 
plt.ylabel("Number of images") 
plt.title("Training Set") 
plt.show()
# Out:
# 3963 4097 4959 4959 4862 3202

# %%
plt.bar(classes, [angry_in_val,fear_in_val,happy_in_val,neutral_in_val,sad_in_val,surprise_in_val], color ='blue',  
        width = 0.7) 
print([angry_in_val,fear_in_val,happy_in_val,neutral_in_val,sad_in_val,surprise_in_val])
  
plt.xlabel("Classes") 
plt.ylabel("Number of images") 
plt.title("Validation Set") 
plt.show()
# Out:
# [495, 512, 620, 620, 608, 400]

# %%
Training_data_size=angry_in_Train+fear_in_Train+happy_in_Train+neutral_in_Train+sad_in_Train+surprise_in_Train
Testing_data_size=angry_in_Test+fear_in_Test+happy_in_Test+neutral_in_Test+sad_in_Test+surprise_in_Test
Validation_data_size=angry_in_val+fear_in_val+happy_in_val+neutral_in_val+sad_in_val+surprise_in_val

Total=Training_data_size+Testing_data_size+Validation_data_size

# %%
labels = ['Train', 'Test', 'Validation']
sizes = [Training_data_size,Testing_data_size , Validation_data_size]

print("Number of images in training data : ",Training_data_size)
print("Number of images in testing data : ",Testing_data_size)
print("Number of images in validation data : ",Validation_data_size)
fig1, ax1 = plt.subplots()
ax1.pie(sizes,labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal') 
plt.show()
# Out:
# Number of images in training data :  26042
# Number of images in testing data :  3251
# Number of images in validation data :  3255
